# %%
#clear all
# %reset -f

#import packages
import numpy as np
import scipy
import sys
import os
import pandas as pd
import mne
import matplotlib
from sklearn.utils import resample
from mne_icalabel import label_components

root = 'F:/Documents/Science/MirRevAdaptEEG'
participants = list(range(0,32))
#specify which erp we are analyzing
erps = 'frn'

#pop up plots as separate window & interactive
# %matplotlib qt
matplotlib.pyplot.close('all')

# %%
# First, we get the 800 timepoints we are considering as a list, to use for indices given by cluster-based permutation later
# But only grab 0 to 1 sec time-locked to feedback onset (idx= 400:601)
root_directory = root
data_directory = os.path.join(root_directory, 'data/eeg/')
pp = 0 #only need one participant

# we can use aligned data

id_directory = os.path.join(data_directory, 'p%03d/' % pp)
pp_directory = os.path.join(id_directory, erps)
fname = os.path.join(pp_directory, 'p%03d_%s_%s-ave.fif' % (pp, 'early_late', 'aligned'))
evoked = mne.read_evokeds(fname)
df = evoked[0].to_data_frame()
time = df['time'].tolist()
time = time[400:601] #get only timepoints we want
# Out:
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)

# %%
# Load data for each condition
# Take the mean across electrodes of interest per participant
# transform data into array accepted for cluster-based permutation test in mne
# output: (n_participants, n_timepts) for each condition

root_directory = root
data_directory = os.path.join(root_directory, 'data/eeg/')

#specify channels we need - FRN
channels = ['FCz', 'F3', 'Fz', 'F4', 'C3', 'Cz', 'C4', 'P3', 'Pz', 'P4']

    
#read in evoked object
tasknames = ['rot', 'rdm', 'mir']
conditionnames = ['early', 'late']


#aligned
evoked_list = []

for pp in participants:
    id_directory = os.path.join(data_directory, 'p%03d/' % participants[pp])
    pp_directory = os.path.join(id_directory, erps)
    fname = os.path.join(pp_directory, 'p%03d_%s_%s-ave.fif' % (participants[pp], 'early_late', 'aligned'))
    evoked = mne.read_evokeds(fname)
    evoked = evoked[0]
    evoked = evoked.get_data(picks=channels) #will give data of shape (n_channels, n_timepts)
    evoked = evoked.mean(axis=0) #take mean of cols or the channels we picked
    evoked = evoked[400:601] #get timepoints we need
    evoked_list.append(evoked)
    
aligned_flist = evoked_list

#rot and rdm and mir
for task in range(0, len(tasknames)):
    for condition in range(0, len(conditionnames)):
        evoked_list = []
        for pp in participants:
            id_directory = os.path.join(data_directory, 'p%03d/' % participants[pp])
            pp_directory = os.path.join(id_directory, erps)
            fname = os.path.join(pp_directory, 'p%03d_%s_%s-ave.fif' % (participants[pp], conditionnames[condition], tasknames[task]))
            evoked = mne.read_evokeds(fname)
            evoked = evoked[0]
            evoked = evoked.get_data(picks=channels) #will give data of shape (n_channels, n_timepts)
            evoked = evoked.mean(axis=0) #take mean of cols or the channels we picked
            evoked = evoked[400:601] #get timepoints we need
            evoked_list.append(evoked)
        if task == 0 and condition == 0:
            early_rot_flist = evoked_list
        elif task == 0 and condition == 1:
            late_rot_flist = evoked_list
        elif task == 1 and condition == 0:
            early_rdm_flist = evoked_list
        elif task == 1 and condition == 1:
            late_rdm_flist = evoked_list
        elif task == 2 and condition == 0:
            early_mir_flist = evoked_list
        elif task == 2 and condition == 1:
            late_mir_flist = evoked_list
# Out:
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_early_late_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_early_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 35 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_late_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_early_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# ...
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_early_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 12 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_late_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-0.1, 0] sec)

# %%
# Comparing males and females would be an independent samples comparison
# permutation function should be modified
# F dist used here, but oneway F test = independent t test when dealing with two independent conditions only
def get_ind_clust_perm_test(conditionA, conditionB, pval, n_permutations, n_conditions = 2):
    #define cluster forming threshold based on p-value
    dfn = n_conditions - 1  # degrees of freedom numerator
    dfd = len(participants) - n_conditions  # degrees of freedom denominator
    thresh = scipy.stats.f.ppf(1 - pval, dfn=dfn, dfd=dfd)  
    #run cluster-based permutation test
    F_0, clust_idx, clust_pvals, H0 = mne.stats.permutation_cluster_test([conditionA, conditionB], threshold = thresh, 
                                                          n_permutations = n_permutations, tail = 0, 
                                                          adjacency = None, seed = 999, 
                                                          out_type = 'mask', verbose = True)

    return F_0, clust_idx, clust_pvals, H0

# %%
# Next, we subtract aligned from each condition, so that we can compare early vs late in each perturbation type
diffconds = ['earlyrot', 'laterot', 'earlyrdm', 'laterdm', 'earlymir', 'latemir']
earlyrot_diff = []
laterot_diff = []
earlyrdm_diff = []
laterdm_diff = []
earlymir_diff = []
latemir_diff = []

for cond in range(0, len(diffconds)):
    if cond == 0:
        diffevks = np.subtract(early_rot_flist, aligned_flist)
        earlyrot_diff.append(diffevks)
        earlyrot_diff = earlyrot_diff[0] #to keep shape of object consistent
    elif cond == 1:
        diffevks = np.subtract(late_rot_flist, aligned_flist)
        laterot_diff.append(diffevks)
        laterot_diff = laterot_diff[0]
    elif cond == 2:
        diffevks = np.subtract(early_rdm_flist, aligned_flist)
        earlyrdm_diff.append(diffevks)
        earlyrdm_diff = earlyrdm_diff[0]
    elif cond == 3:
        diffevks = np.subtract(late_rdm_flist, aligned_flist)
        laterdm_diff.append(diffevks)
        laterdm_diff = laterdm_diff[0]
    elif cond == 4:
        diffevks = np.subtract(early_mir_flist, aligned_flist)
        earlymir_diff.append(diffevks)
        earlymir_diff = earlymir_diff[0]
    elif cond == 5:
        diffevks = np.subtract(late_mir_flist, aligned_flist)
        latemir_diff.append(diffevks)
        latemir_diff =latemir_diff[0]

# %%
# Next step is to subtract early from late condition, to generate a single signal for each perturbation
diffconds = ['rot', 'rdm', 'mir']
rot_diff = []
rdm_diff = []
mir_diff = []

for cond in range(0, len(diffconds)):
    if cond == 0:
        diffevks = np.subtract(laterot_diff, earlyrot_diff)
        rot_diff.append(diffevks)
        rot_diff = rot_diff[0] #to keep shape of object consistent
    elif cond == 1:
        diffevks = np.subtract(laterdm_diff, earlyrdm_diff)
        rdm_diff.append(diffevks)
        rdm_diff = rdm_diff[0]
    elif cond == 2:
        diffevks = np.subtract(latemir_diff, earlymir_diff)
        mir_diff.append(diffevks)
        mir_diff = mir_diff[0]

# %%
#separate by sex
rot_males = rot_diff[[0,3,4,5,8,12,14,15,16,17,19,20,23,24,26,27,28,30,31]]
rot_females = rot_diff[[1,2,6,7,9,10,11,13,18,21,22,25,29]]

rdm_males = rdm_diff[[0,3,4,5,8,12,14,15,16,17,19,20,23,24,26,27,28,30,31]]
rdm_females = rdm_diff[[1,2,6,7,9,10,11,13,18,21,22,25,29]]

mir_males = mir_diff[[0,3,4,5,8,12,14,15,16,17,19,20,23,24,26,27,28,30,31]]
mir_females = mir_diff[[1,2,6,7,9,10,11,13,18,21,22,25,29]]

# %%
# Generate a data frame to tabulate condition, cluster indices, cluster timepts, p values of PERTURBATION comparisons
# This information can then be included in ERP difference wave plots

conds = ['rot_mf', 'rdm_mf', 'mir_mf']
conditionnames = ['rot_mvf', 'rdm_mvf', 'mir_mvf']
p = 0.05
perms = 1000

condition = []
clust_idx_start = []
clust_idx_end = []
time_start = []
time_end = []
p_values = []

for c in range(0, len(conds)):
    if c == 0:
        T_0, clust_idx, clust_pvals, H0 = get_ind_clust_perm_test(rot_males, rot_females, p, perms)
#         print(clust_idx, clust_pvals)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
            
    elif c == 1:
        T_0, clust_idx, clust_pvals, H0 = get_ind_clust_perm_test(rdm_males, rdm_females, p, perms)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
            
    elif c == 2:
        T_0, clust_idx, clust_pvals, H0 = get_ind_clust_perm_test(mir_males, mir_females, p, perms)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
        
perm_test = pd.DataFrame(
    {'condition': condition,
     'clust_idx_start': clust_idx_start,
     'clust_idx_end': clust_idx_end,
     'time_start': time_start,
     'time_end': time_end,
     'p_values': p_values})

perm_test_filename = os.path.join('F:/Documents/Science/MirRevAdaptEEG/data/sex_diff/', 'Permutation_test_EvL_PerturbTypeComp_SexDIFF_%s.csv' % (erps))
perm_test.to_csv(perm_test_filename)
# Out:
# stat_fun(H1): min=0.000001 max=5.406443
# Running initial clustering …
# Found 2 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=0.000004 max=3.392492
# Running initial clustering …
# Found 0 clusters
# stat_fun(H1): min=0.000007 max=2.447556
# Running initial clustering …
# Found 0 clusters
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_19252\4221181891.py:10: RuntimeWarning: No clusters found, returning empty H0, clusters, and cluster_pv
#   F_0, clust_idx, clust_pvals, H0 = mne.stats.permutation_cluster_test([conditionA, conditionB], threshold = thresh,
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_19252\4221181891.py:10: RuntimeWarning: No clusters found, returning empty H0, clusters, and cluster_pv
#   F_0, clust_idx, clust_pvals, H0 = mne.stats.permutation_cluster_test([conditionA, conditionB], threshold = thresh,
