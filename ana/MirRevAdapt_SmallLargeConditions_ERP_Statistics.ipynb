# %%
#clear all
# %reset -f

#import packages
import numpy as np
import scipy
import sys
import os
import pandas as pd
import mne
import matplotlib
from sklearn.utils import resample
from mne_icalabel import label_components

root = 'F:/Documents/Science/MirRevAdaptEEG'
participants = list(range(0,32))
#specify which erp we are analyzing
erps = 'frn'

#pop up plots as separate window & interactive
# %matplotlib qt
matplotlib.pyplot.close('all')

# %%
# First, we get the 800 timepoints we are considering as a list, to use for indices given by cluster-based permutation later
# But only grab -0.25 to 1.5 sec time-locked to feedback onset (idx= 350:701)
root_directory = root
data_directory = os.path.join(root_directory, 'data/eeg/')
pp = 0 #only need one participant

# we can use aligned data

id_directory = os.path.join(data_directory, 'p%03d/' % pp)
pp_directory = os.path.join(id_directory, erps)
fname = os.path.join(pp_directory, 'p%03d_%s_%s-ave.fif' % (pp, 'small_large', 'aligned'))
evoked = mne.read_evokeds(fname)
df = evoked[0].to_data_frame()
time = df['time'].tolist()
time = time[350:701] #get only timepoints we want
# Out:
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)

# %%
# Load data for each condition
# Take the mean across electrodes of interest per participant
# transform data into array accepted for cluster-based permutation test in mne
# output: (n_participants, n_timepts) for each condition

root_directory = root
data_directory = os.path.join(root_directory, 'data/eeg/')

#specify channels we need - FRN
channels = ['FCz', 'F3', 'Fz', 'F4', 'C3', 'Cz', 'C4', 'P3', 'Pz', 'P4']

    
#read in evoked object
tasknames = ['rot', 'rdm', 'mir']
conditionnames = ['smlerrors', 'lrgerrors']


#aligned
evoked_list = []

for pp in participants:
    id_directory = os.path.join(data_directory, 'p%03d/' % participants[pp])
    pp_directory = os.path.join(id_directory, erps)
    fname = os.path.join(pp_directory, 'p%03d_%s_%s-ave.fif' % (participants[pp], 'small_large', 'aligned'))
    evoked = mne.read_evokeds(fname)
    evoked = evoked[0]
    evoked = evoked.get_data(picks=channels) #will give data of shape (n_channels, n_timepts)
    evoked = evoked.mean(axis=0) #take mean of cols or the channels we picked
    evoked = evoked[350:701] #get timepoints we need
    evoked_list.append(evoked)
    
aligned_flist = evoked_list

#rot and rdm and mir
for task in range(0, len(tasknames)):
    for condition in range(0, len(conditionnames)):
        evoked_list = []
        for pp in participants:
            id_directory = os.path.join(data_directory, 'p%03d/' % participants[pp])
            pp_directory = os.path.join(id_directory, erps)
            fname = os.path.join(pp_directory, 'p%03d_%s_%s-ave.fif' % (participants[pp], conditionnames[condition], tasknames[task]))
            evoked = mne.read_evokeds(fname)
            evoked = evoked[0]
            evoked = evoked.get_data(picks=channels) #will give data of shape (n_channels, n_timepts)
            evoked = evoked.mean(axis=0) #take mean of cols or the channels we picked
            evoked = evoked[350:701] #get timepoints we need
            evoked_list.append(evoked)
        if task == 0 and condition == 0:
            sml_rot_flist = evoked_list
        elif task == 0 and condition == 1:
            lrg_rot_flist = evoked_list
        elif task == 1 and condition == 0:
            sml_rdm_flist = evoked_list
        elif task == 1 and condition == 1:
            lrg_rdm_flist = evoked_list
        elif task == 2 and condition == 0:
            sml_mir_flist = evoked_list
        elif task == 2 and condition == 1:
            lrg_mir_flist = evoked_list
# Out:
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_small_large_aligned-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 48 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_smlerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 35 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_lrgerrors_rot-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 42 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_smlerrors_rdm-ave.fif ...
#     Found the data of interest:
# ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_smlerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_smlerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_smlerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_smlerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_smlerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_smlerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p000\frn\p000_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p001\frn\p001_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p002\frn\p002_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p003\frn\p003_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p004\frn\p004_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p005\frn\p005_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p006\frn\p006_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p007\frn\p007_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p008\frn\p008_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p009\frn\p009_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p010\frn\p010_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p011\frn\p011_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p012\frn\p012_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p013\frn\p013_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p014\frn\p014_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p015\frn\p015_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p016\frn\p016_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p017\frn\p017_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p018\frn\p018_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p019\frn\p019_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p020\frn\p020_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p021\frn\p021_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p022\frn\p022_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p023\frn\p023_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p024\frn\p024_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p025\frn\p025_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 37 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p026\frn\p026_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 35 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p027\frn\p027_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p028\frn\p028_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p029\frn\p029_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p030\frn\p030_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)
# Reading F:\Documents\Science\MirRevAdaptEEG\data\eeg\p031\frn\p031_lrgerrors_mir-ave.fif ...
#     Found the data of interest:
#         t =   -2000.00 ...    1995.00 ms (16142)
#         0 CTF compensation matrices available
#         nave = 36 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1.5, -1.2] sec)

# %%
# Comparing two ERP signals is just the same as taking their difference (ERP1 minus ERP2) and using this in permutation test
def get_clust_perm_test(conditionA, conditionB, pval, n_permutations):
    #take difference of two conditions
    data = np.subtract(conditionA, conditionB)
    #np.shape(data)
    #define cluster forming threshold based on p-value
    df = len(participants) - 1
    thresh = scipy.stats.t.ppf(1 - pval / 2, df)
    #run cluster-based permutation test
    T_0, clust_idx, clust_pvals, H0 = mne.stats.permutation_cluster_1samp_test(data, threshold = thresh, 
                                                          n_permutations = n_permutations, tail = 0, 
                                                          adjacency = None, seed = 999, 
                                                          out_type = 'mask', verbose = True)

    return T_0, clust_idx, clust_pvals, H0

# %%
# First, we can compare each condition to aligned
# Generate a data frame to tabulate condition, cluster indices, cluster timepts, p values
# This information can then be included in ERP plots

flists = [sml_rot_flist, lrg_rot_flist, sml_rdm_flist, lrg_rdm_flist, sml_mir_flist, lrg_mir_flist]
conditionnames = ['smallrot', 'largerot', 'smallrdm', 'largerdm', 'smallmir', 'largemir']
p = 0.05
perms = 1000

condition = []
clust_idx_start = []
clust_idx_end = []
time_start = []
time_end = []
p_values = []

for f in range(0, len(flists)):
    T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(flists[f], aligned_flist, p, perms)
#     print(clust_idx, clust_pvals)
    if len(clust_idx) == 0:
        condition.append(conditionnames[c])
        clust_idx_start.append(np.nan)
        clust_idx_end.append(np.nan)
        time_start.append(np.nan)
        time_end.append(np.nan)
        p_values.append(np.nan)
    else:
        for clust in range(0, len(clust_idx)):
            cluster = clust_idx[clust][0] #to get the slice sequence we need
        
            cluster_start = cluster.start
            clust_idx_start.append(cluster_start)
        
            cluster_end = cluster.stop
            clust_idx_end.append(cluster_end)
        
            time_idx_start = time[cluster_start]
            time_start.append(time_idx_start)
        
            time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
            time_end.append(time_idx_end)
        
            clust_p = clust_pvals[clust]
            p_values.append(clust_p)
        
            condition.append(conditionnames[f])
        
perm_test = pd.DataFrame(
    {'condition': condition,
     'clust_idx_start': clust_idx_start,
     'clust_idx_end': clust_idx_end,
     'time_start': time_start,
     'time_end': time_end,
     'p_values': p_values})

perm_test_filename = os.path.join('F:/Documents/Science/MirRevAdaptEEG/data/', 'Permutation_test_vsAligned_SmallLarge_%s.csv' % (erps))
perm_test.to_csv(perm_test_filename)
# Out:
# stat_fun(H1): min=-2.711827 max=3.558765
# Running initial clustering …
# Found 7 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-2.784388 max=1.802399
# Running initial clustering …
# Found 3 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-2.559134 max=4.160653
# Running initial clustering …
# Found 6 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-1.923760 max=5.203892
# Running initial clustering …
# Found 1 cluster
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-0.287277 max=4.219008
# Running initial clustering …
# Found 3 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-2.899714 max=1.750117
# Running initial clustering …
# Found 5 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]

# %%
# Next, we subtract aligned from each condition, so that we can compare small vs late in each perturbation type
diffconds = ['smallrot', 'largerot', 'smallrdm', 'largerdm', 'smallmir', 'largemir']
smallrot_diff = []
largerot_diff = []
smallrdm_diff = []
largerdm_diff = []
smallmir_diff = []
largemir_diff = []

for cond in range(0, len(diffconds)):
    if cond == 0:
        diffevks = np.subtract(sml_rot_flist, aligned_flist)
        smallrot_diff.append(diffevks)
        smallrot_diff = smallrot_diff[0] #to keep shape of object consistent
    elif cond == 1:
        diffevks = np.subtract(lrg_rot_flist, aligned_flist)
        largerot_diff.append(diffevks)
        largerot_diff = largerot_diff[0]
    elif cond == 2:
        diffevks = np.subtract(sml_rdm_flist, aligned_flist)
        smallrdm_diff.append(diffevks)
        smallrdm_diff = smallrdm_diff[0]
    elif cond == 3:
        diffevks = np.subtract(lrg_rdm_flist, aligned_flist)
        largerdm_diff.append(diffevks)
        largerdm_diff = largerdm_diff[0]
    elif cond == 4:
        diffevks = np.subtract(sml_mir_flist, aligned_flist)
        smallmir_diff.append(diffevks)
        smallmir_diff = smallmir_diff[0]
    elif cond == 5:
        diffevks = np.subtract(lrg_mir_flist, aligned_flist)
        largemir_diff.append(diffevks)
        largemir_diff =largemir_diff[0]

# %%
# Generate a data frame to tabulate condition, cluster indices, cluster timepts, p values of EARLY VS LATE comparisons
# This information can then be included in ERP difference wave plots

conds = ['rot_diff', 'rdm_diff', 'mir_diff']
conditionnames = ['rot', 'rdm', 'mir']
p = 0.05
perms = 1000

condition = []
clust_idx_start = []
clust_idx_end = []
time_start = []
time_end = []
p_values = []

for c in range(0, len(conds)):
    if c == 0:
        T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(largerot_diff, smallrot_diff, p, perms)
#         print(clust_idx, clust_pvals)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
            
    elif c == 1:
        T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(largerdm_diff, smallrdm_diff, p, perms)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:    
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
            
    elif c == 2:
        T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(largemir_diff, smallmir_diff, p, perms)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:    
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
        
perm_test = pd.DataFrame(
    {'condition': condition,
     'clust_idx_start': clust_idx_start,
     'clust_idx_end': clust_idx_end,
     'time_start': time_start,
     'time_end': time_end,
     'p_values': p_values})

perm_test_filename = os.path.join('F:/Documents/Science/MirRevAdaptEEG/data/', 'Permutation_test_SmallvsLarge_%s.csv' % (erps))
perm_test.to_csv(perm_test_filename)
# Out:
# stat_fun(H1): min=-2.916617 max=0.060636
# Running initial clustering …
# Found 6 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-1.569992 max=2.053548
# Running initial clustering …
# Found 1 cluster
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-4.260790 max=-1.686482
# Running initial clustering …
# Found 2 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]

# %%
# Next step is to subtract early from late condition, to generate a single signal for each perturbation
diffconds = ['rot', 'rdm', 'mir']
rot_diff = []
rdm_diff = []
mir_diff = []

for cond in range(0, len(diffconds)):
    if cond == 0:
        diffevks = np.subtract(largerot_diff, smallrot_diff)
        rot_diff.append(diffevks)
        rot_diff = rot_diff[0] #to keep shape of object consistent
    elif cond == 1:
        diffevks = np.subtract(largerdm_diff, smallrdm_diff)
        rdm_diff.append(diffevks)
        rdm_diff = rdm_diff[0]
    elif cond == 2:
        diffevks = np.subtract(largemir_diff, smallmir_diff)
        mir_diff.append(diffevks)
        mir_diff = mir_diff[0]

# %%
# Generate a data frame to tabulate condition, cluster indices, cluster timepts, p values of PERTURBATION comparisons
# This information can then be included in ERP difference wave plots

conds = ['rotvmir', 'rotvrdm', 'mirvrdm']
conditionnames = ['rotvmir', 'rotvrdm', 'mirvrdm']
p = 0.05
perms = 1000

condition = []
clust_idx_start = []
clust_idx_end = []
time_start = []
time_end = []
p_values = []

for c in range(0, len(conds)):
    if c == 0:
        T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(rot_diff, mir_diff, p, perms)
#         print(clust_idx, clust_pvals)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
            
    elif c == 1:
        T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(rot_diff, rdm_diff, p, perms)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
            
    elif c == 2:
        T_0, clust_idx, clust_pvals, H0 = get_clust_perm_test(mir_diff, rdm_diff, p, perms)
        if len(clust_idx) == 0:
            condition.append(conditionnames[c])
            clust_idx_start.append(np.nan)
            clust_idx_end.append(np.nan)
            time_start.append(np.nan)
            time_end.append(np.nan)
            p_values.append(np.nan)
        else:
            for clust in range(0, len(clust_idx)):
                cluster = clust_idx[clust][0] #to get the slice sequence we need
        
                cluster_start = cluster.start
                clust_idx_start.append(cluster_start)
        
                cluster_end = cluster.stop
                clust_idx_end.append(cluster_end)
        
                time_idx_start = time[cluster_start]
                time_start.append(time_idx_start)
        
                time_idx_end = time[cluster_end - 1] #minus one because python indexing does not include ending value
                time_end.append(time_idx_end)
        
                clust_p = clust_pvals[clust]
                p_values.append(clust_p)
        
                condition.append(conditionnames[c])
        
perm_test = pd.DataFrame(
    {'condition': condition,
     'clust_idx_start': clust_idx_start,
     'clust_idx_end': clust_idx_end,
     'time_start': time_start,
     'time_end': time_end,
     'p_values': p_values})

perm_test_filename = os.path.join('F:/Documents/Science/MirRevAdaptEEG/data/', 'Permutation_test_SmallLarge_PerturbTypeComp_%s.csv' % (erps))
perm_test.to_csv(perm_test_filename)
# Out:
# stat_fun(H1): min=0.723090 max=2.989942
# Running initial clustering …
# Found 5 clusters
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
# stat_fun(H1): min=-1.949165 max=-0.236483
# Running initial clustering …
# Found 0 clusters
# stat_fun(H1): min=-3.364068 max=-1.445638
# Running initial clustering …
# Found 6 clusters
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_9380\822222689.py:10: RuntimeWarning: No clusters found, returning empty H0, clusters, and cluster_pv
#   T_0, clust_idx, clust_pvals, H0 = mne.stats.permutation_cluster_1samp_test(data, threshold = thresh,
#   0%|          | Permuting : 0/999 [00:00<?,       ?it/s]
